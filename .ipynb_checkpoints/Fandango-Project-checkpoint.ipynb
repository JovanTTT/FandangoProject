# %% [markdown]
# # Fandango Project
# ## Overview
#
# When considering going out to watch a movie, how reliable are online reviews and ratings? Particularly when the platform displaying the ratings also profits from ticket sales. Is there a tendency for such companies to inflate ratings to encourage ticket purchases?
#
# ### Goal:
#
# **My goal is to find out does the company makes higher movie ratings just to sell higher
# amount of the tickets.**
#
# ---
# ---
#
# ## Understanding the Background and Data
#
#
# **For a better understanding of my motivation for making this project, read this article: [Be Suspicious Of Online Movie Ratings, Especially Fandango’s](http://fivethirtyeight.com/features/fandango-movies-ratings/)**

# %% [markdown]
# ### The Data
#
# This is the data behind the story [Be Suspicious Of Online Movie Ratings, Especially Fandango’s](http://fivethirtyeight.com/features/fandango-movies-ratings/) openly available on 538's github: https://github.com/fivethirtyeight/data.

# %% [markdown]
# ----
# ----
#
# #### all_sites_scores.csv

# %% [markdown]
# -----
#
# `all_sites_scores.csv` contains every film that has a Rotten Tomatoes rating, a RT User rating, a Metacritic score, a Metacritic User score, and IMDb score, and at least 30 fan reviews on Fandango. The data from Fandango was pulled on Aug. 24, 2015.

# %% [markdown]
# Column | Definition
# --- | -----------
# FILM | The film in question
# RottenTomatoes | The Rotten Tomatoes Tomatometer score  for the film
# RottenTomatoes_User | The Rotten Tomatoes user score for the film
# Metacritic | The Metacritic critic score for the film
# Metacritic_User | The Metacritic user score for the film
# IMDB | The IMDb user score for the film
# Metacritic_user_vote_count | The number of user votes the film had on Metacritic
# IMDB_user_vote_count | The number of user votes the film had on IMDb

# %% [markdown]
# ----
# ----
#
# #### fandango_scape.csv

# %% [markdown]
# `fandango_scrape.csv` contains every film 538 pulled from Fandango.
#
# Column | Definiton
# --- | ---------
# FILM | The movie
# STARS | Number of stars presented on Fandango.com
# RATING |  The Fandango ratingValue for the film, as pulled from the HTML of each page. This is the actual average score the movie obtained.
# VOTES | number of people who had reviewed the film at the time we pulled it.

# %% [markdown]
# ----
#
# **TASK: Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %% [markdown]
# ## Exploring Fandango Displayed Scores versus True User Ratings
#
# Let's first explore the Fandango ratings to see if our analysis agrees with the article's conclusion.
#
# **TASK: Opening fandango_scrape.csv file**

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %%
fandango
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 499                      Valiyavan (2015)    0.0     0.0      0
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 503                         Zarafa (2012)    0.0     0.0      0
#
# [504 rows x 4 columns]

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %% [markdown]
# **TASK: I want to explore the relationship between popularity of a film and its rating.**

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.scatterplot(data = fandango, x = 'RATING', y = 'VOTES');

# %% [markdown]
# **TASK: Calculating the correlation between the columns:**

# %%
correlation = fandango.drop('FILM', axis = 1)
correlation.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %% [markdown]
# **TASK: Assuming that every row in the FILM title column has the same format:**
#
#     Film Title Name (Year)
#
# **I am going to create a new column that is able to strip the year from the title strings and set this new column as YEAR**

# %%
fandango['YEAR'] = fandango['FILM'].apply(lambda movie : movie.split('(')[-1].strip(')'))
fandango['YEAR']
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: YEAR, Length: 504, dtype: object

# %% [markdown]
# **TASK: Calculating how many movies are in the Fandango DataFrame per year?**

# %%
fandango['YEAR'].value_counts()
# Out:
# YEAR
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: count, dtype: int64

# %% [markdown]
# **TASK: I am going to visualize the count of movies per year with a plot:**

# %%
sns.countplot(data = fandango, x = 'YEAR')
# Out:
# <Axes: xlabel='YEAR', ylabel='count'>

# %% [markdown]
# **TASK: What are the 10 movies with the highest number of votes?**

# %%
fandango.sort_values('VOTES', ascending = False).iloc[:10]
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %% [markdown]
# **TASK: How many movies have zero votes?**

# %%
len(fandango[fandango['VOTES'] == 0])
# Out:
# 69

# %% [markdown]
# **TASK: Creating DataFrame of only reviewed films by removing any films that have zero votes.**

# %%
fandangoNonZeroVotes = fandango[fandango['VOTES'] != 0]
fandangoNonZeroVotes.reset_index()
fandangoNonZeroVotes
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1          Jurassic World (2015)    4.5     4.5  34390  2015
# 2         American Sniper (2015)    5.0     4.8  34085  2015
# 3               Furious 7 (2015)    5.0     4.8  33538  2015
# 4              Inside Out (2015)    4.5     4.5  15749  2015
# ..                           ...    ...     ...    ...   ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015
# 431            The Intern (2015)    5.0     5.0      1  2015
# 432        The Park Bench (2015)    5.0     5.0      1  2015
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015
#
# [435 rows x 5 columns]

# %% [markdown]
# ----
#
# **As noted in the article, due to HTML and star rating displays, the true user rating may be slightly different than the rating shown to a user. Let's visualize this difference in distributions.**
#
# **TASK: Creating a KDE plot that displays the distribution of ratings that are displayed (STARS) versus what the true rating was from votes (RATING). Clip the KDEs to 0-5.**

# %%
plt.figure(figsize = (10, 5))
sns.kdeplot(data = fandangoNonZeroVotes, x = 'RATING', clip = [0, 5], fill = True, label = 'True Rating')
sns.kdeplot(data = fandangoNonZeroVotes, x = 'STARS', clip = [0, 5], fill = True, label = 'Stars Displayed')
plt.legend(loc = (1.04, 0.5));

# %% [markdown]
# **TASK: Let's now actually quantify this discrepancy. I am goint to create a new column of the different between STARS displayed versus true RATING. Calculate this difference with STARS-RATING and round these differences to the nearest decimal point.**

# %%
fandangoNonZeroVotes.loc[:, 'STARS-RATING'] = round(fandangoNonZeroVotes['STARS'] - fandangoNonZeroVotes['RATING'], 1)
fandangoNonZeroVotes
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS-RATING
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015           0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015           0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015           0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015           0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015           0.0
# ..                           ...    ...     ...    ...   ...           ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015           0.0
# 431            The Intern (2015)    5.0     5.0      1  2015           0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015           0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015           0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015           0.0
#
# [435 rows x 6 columns]

# %% [markdown]
# **TASK: Creating a count plot to display the number of times a certain difference occurs:**

# %%
plt.figure(figsize = (12, 4), dpi = 100)
sns.countplot(data = fandangoNonZeroVotes, x = 'STARS-RATING', palette = 'magma');

# %% [markdown]
# **TASK: We can see from the plot that a small number of movies displayed a difference of over 1 star from their true rating. Which movies had a differential close to 1 star?**

# %%
fandangoNonZeroVotes[fandangoNonZeroVotes['STARS-RATING'] >= 1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS-RATING
# 381  Turbo Kid (2015)    5.0     4.0      2  2015           1.0

# %% [markdown]
# ## Comparison of Fandango Ratings to Other Sites
#
# LI want to compare the scores from Fandango to other movies sites and see how they compare.

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %%
all_sites
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# 2                     90          64              8.1   7.8
# 3                     84          22              4.7   5.4
# 4                     28          29              3.4   5.1
# ..                   ...         ...              ...   ...
# 141                   78          67              7.9   7.4
# 142                   82          83              7.5   7.2
# 143                   78          89              8.8   7.4
# 144                   81          90              7.3   7.8
# 145                   63          68              6.4   6.7
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 0                          1330                271107
# 1                           249                 65709
# 2                           627                103660
# 3                            31                  3136
# 4                            88                 19560
# ..                          ...                   ...
# 141                          33                  7367
# 142                          60                 24116
# 143                         123                 24345
# 144                          19                  1955
# 145                          19                  5289
#
# [146 rows x 8 columns]

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.3+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# min      4.000000                    4.000000            243.000000
# 25%      6.300000                   33.250000           5627.000000
# 50%      6.900000                   72.500000          19103.000000
# 75%      7.400000                  168.500000          45185.750000
# max      8.600000                 2375.000000         334164.000000

# %% [markdown]
# ### Rotten Tomatoes
#
# Let's first take a look at Rotten Tomatoes. RT has two sets of reviews, their critics reviews (ratings published by official critics) and user reviews.
#
# **TASK: I am going to create a scatterplot exploring the relationship between RT Critic reviews and RT User reviews.**

# %%
plt.figure(figsize = (12, 6), dpi = 200)
plt.axes([0 ,0, 0.5, 0.5])
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.title('RottenTomatoes vs RottenTomatoes_User')
sns.scatterplot(data = all_sites, x = 'RottenTomatoes', y = 'RottenTomatoes_User', alpha = 0.5)
# Out:
# <Axes: title={'center': 'RottenTomatoes vs RottenTomatoes_User'}, xlabel='RottenTomatoes', ylabel='RottenTomatoes_User'>

# %% [markdown]
# Let's quantify this difference by comparing the critics ratings and the RT User ratings. I will calculate this with RottenTomatoes-RottenTomatoes_User. Note: Rotten_Diff here is Critics - User Score. So values closer to 0 means aggrement between Critics and Users. Larger positive values means critics rated much higher than users. Larger negative values means users rated much higher than critics.
#
# **TASK: I am going to create a new column based off the difference between critics ratings and users ratings for Rotten Tomatoes. Calculate this with RottenTomatoes-RottenTomatoes_User**

# %%
all_sites['Rotten_Diff'] = all_sites['RottenTomatoes'] - all_sites['RottenTomatoes_User']
all_sites['Rotten_Diff']
# Out:
# 0     -12
# 1       5
# 2     -10
# 3     -66
# 4     -14
#        ..
# 141     9
# 142    15
# 143    19
# 144    19
# 145    24
# Name: Rotten_Diff, Length: 146, dtype: int64

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# 2                103660          -10
# 3                  3136          -66
# 4                 19560          -14

# %% [markdown]
# Let's now compare the overall mean difference. Since we're dealing with differences that could be negative or positive, first i am going to take the absolute value of all the differences, then take the mean. This would report back on average to absolute difference between the critics rating versus the user rating.

# %%
round(abs(all_sites['Rotten_Diff']).mean(), 2)
# Out:
# 15.1

# %% [markdown]
# **TASK: Plot the distribution of the differences between RT Critics Score and RT User Score. There should be negative values in this distribution plot.**

# %%
plt.figure(figsize = (12, 5), dpi = 200)
plt.title('RT Critics Score - RT User Score')
sns.histplot(data = all_sites, x = 'Rotten_Diff', kde = True, bins = 25)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'RT Critics Score - RT User Score'}, xlabel='Rotten_Diff', ylabel='Count'>

# %% [markdown]
# **TASK: Now I am going to create a distribution showing the *absolute value* difference between Critics and Users on Rotten Tomatoes.**

# %%
plt.figure(figsize = (12, 5), dpi = 250)
plt.title('Abs difference between RT Critics and RT User Score')
sns.histplot(data = all_sites, x = abs(all_sites['Rotten_Diff']), bins = 25, kde = True, color = 'brown', edgecolor = 'beige');
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Let's find out which movies are causing the largest differences. First, i will show the top 5 movies with the largest *negative* difference between Users and RT critics. Since I calculated the difference as Critics Rating - Users Rating, then large negative values imply the users rated the movie much higher on average than the critics did.**

# %%
all_sites.sort_values('Rotten_Diff', ascending = True)[['FILM', 'Rotten_Diff']].iloc[:5]
#all_sites.nlargest(5,'Rotten_Diff')[['FILM','Rotten_Diff']]
# Out:
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 134    The Longest Ride (2015)          -42
# 105    Hitman: Agent 47 (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %% [markdown]
# ## MetaCritic
#
# Now let's take a quick look at the ratings from MetaCritic. Metacritic also shows an average user rating versus their official displayed rating.

# %% [markdown]
# **TASK: I am going to display a scatterplot of the Metacritic Rating versus the Metacritic User rating.**

# %%
all_sites
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# 2                     90          64              8.1   7.8
# 3                     84          22              4.7   5.4
# 4                     28          29              3.4   5.1
# ..                   ...         ...              ...   ...
# 141                   78          67              7.9   7.4
# 142                   82          83              7.5   7.2
# 143                   78          89              8.8   7.4
# 144                   81          90              7.3   7.8
# 145                   63          68              6.4   6.7
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 0                          1330                271107
# 1                           249                 65709
# 2                           627                103660
# 3                            31                  3136
# 4                            88                 19560
# ..                          ...                   ...
# 141                          33                  7367
# 142                          60                 24116
# 143                         123                 24345
# 144                          19                  1955
# 145                          19                  5289
#
# [146 rows x 8 columns]

# %%
plt.figure(figsize = (10, 4), dpi = 150)
plt.xlim(10, 100)
plt.ylim(0, 10)
sns.scatterplot(data = all_sites, x = 'Metacritic', y = 'Metacritic_User')
# Out:
# <Axes: xlabel='Metacritic', ylabel='Metacritic_User'>

# %% [markdown]
# ## IMBD
#
# Now I will analyze the IMDB by examining its most popular movies.
#
# **TASK: I am going to create a scatterplot for the relationship between vote counts on MetaCritic versus vote counts on IMDB.**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %%
plt.figure(figsize = (10, 4), dpi = 150)
sns.scatterplot(data = all_sites, x = 'Metacritic_user_vote_count', y = 'IMDB_user_vote_count', color = 'black')
# Out:
# <Axes: xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %% [markdown]
# **Going to find out which film have the highest amount of votes on IMDB**

# %%
all_sites.nlargest(1, 'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count
# 14                334164

# %% [markdown]
# **I want to know how many films have more than 100 000 IMDB votes**

# %%
len(all_sites[all_sites['IMDB_user_vote_count'] > 100000])
# Out:
# 16

# %% [markdown]
# **I displayed those films, in descending order**

# %%
all_sites[all_sites['IMDB_user_vote_count'] > 100000].sort_values('IMDB_user_vote_count', ascending = False)
# Out:
#                                                  FILM  RottenTomatoes  \
# 14                          The Imitation Game (2014)              90
# 65                                     Birdman (2014)              92
# 88                          Mad Max: Fury Road (2015)              97
# 74   The Hobbit: The Battle of the Five Armies (2014)              61
# 44                Kingsman: The Secret Service (2015)              75
# 0                      Avengers: Age of Ultron (2015)              74
# 72                             American Sniper (2015)              72
# 130                             Jurassic World (2015)              71
# 73                                   Furious 7 (2015)              81
# 97                        Fifty Shades of Grey (2015)              25
# 26                                  Ex Machina (2015)              92
# 78                                     Chappie (2015)              30
# 100                          Jupiter Ascending (2015)              26
# 15                                     Taken 3 (2015)               9
# 2                                      Ant-Man (2015)              80
# 99                                       Focus (2015)              57
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 14                    92          73              8.2   8.1
# 65                    78          88              8.0   7.9
# 88                    88          89              8.7   8.3
# 74                    75          59              7.0   7.5
# 44                    84          58              7.9   7.8
# 0                     86          66              7.1   7.8
# 72                    85          72              6.6   7.4
# 130                   81          59              7.0   7.3
# 73                    84          67              6.8   7.4
# 97                    42          46              3.2   4.2
# 26                    86          78              7.9   7.7
# 78                    57          41              7.4   7.0
# 100                   40          40              4.5   5.5
# 15                    46          26              4.6   6.1
# 2                     90          64              8.1   7.8
# 99                    54          56              6.2   6.6
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 14                          566                334164
# 65                         1171                303505
# 88                         2375                292023
# 74                          903                289464
# 44                         1054                272204
# 0                          1330                271107
# 72                          850                251856
# 130                        1281                241807
# 73                          764                207211
# 97                          778                179506
# 26                          672                154499
# 78                          637                125088
# 100                         503                105412
# 15                          240                104235
# 2                           627                103660
# 99                          167                101264

# %% [markdown]
# **I will do the same thing for the Metactiric vote count**

# %%
all_sites.nlargest(1, 'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count
# 88                292023

# %%
len(all_sites[all_sites['Metacritic_user_vote_count'] > 500])
# Out:
# 17

# %%
all_sites[all_sites['Metacritic_user_vote_count'] > 500].sort_values('Metacritic_user_vote_count', ascending = False)
# Out:
#                                                  FILM  RottenTomatoes  \
# 88                          Mad Max: Fury Road (2015)              97
# 0                      Avengers: Age of Ultron (2015)              74
# 130                             Jurassic World (2015)              71
# 65                                     Birdman (2014)              92
# 44                Kingsman: The Secret Service (2015)              75
# 74   The Hobbit: The Battle of the Five Armies (2014)              61
# 72                             American Sniper (2015)              72
# 140                                 Inside Out (2015)              98
# 49                          Terminator Genisys (2015)              26
# 97                        Fifty Shades of Grey (2015)              25
# 73                                   Furious 7 (2015)              81
# 26                                  Ex Machina (2015)              92
# 78                                     Chappie (2015)              30
# 2                                      Ant-Man (2015)              80
# 14                          The Imitation Game (2014)              90
# 112                                 It Follows (2015)              96
# 100                          Jupiter Ascending (2015)              26
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 88                    88          89              8.7   8.3
# 0                     86          66              7.1   7.8
# 130                   81          59              7.0   7.3
# 65                    78          88              8.0   7.9
# 44                    84          58              7.9   7.8
# 74                    75          59              7.0   7.5
# 72                    85          72              6.6   7.4
# 140                   90          94              8.9   8.6
# 49                    60          38              6.4   6.9
# 97                    42          46              3.2   4.2
# 73                    84          67              6.8   7.4
# 26                    86          78              7.9   7.7
# 78                    57          41              7.4   7.0
# 2                     90          64              8.1   7.8
# 14                    92          73              8.2   8.1
# 112                   65          83              7.5   6.9
# 100                   40          40              4.5   5.5
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 88                         2375                292023
# 0                          1330                271107
# 130                        1281                241807
# 65                         1171                303505
# 44                         1054                272204
# 74                          903                289464
# 72                          850                251856
# 140                         807                 96252
# 49                          779                 85585
# 97                          778                179506
# 73                          764                207211
# 26                          672                154499
# 78                          637                125088
# 2                           627                103660
# 14                          566                334164
# 112                         551                 64656
# 100                         503                105412

# %% [markdown]
# ## Fandago Scores vs. All Sites
#
# It's time to explore whether or not Fandango artificially displays higher ratings than warranted to boost ticket sales.

# %% [markdown]
# **TASK: Combine the Fandango Table with the All Sites table. Not every movie in the Fandango table is in the All Sites table, since some Fandango movies have very little or no reviews. We only want to compare movies that are in both DataFrames, so i will do an *inner* merge to merge together both DataFrames based on the FILM columns.**

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %%
rightMerged = pd.merge(fandango, all_sites, how = 'right', on = 'FILM')
rightMerged
# Out:
#                                           FILM  STARS  RATING    VOTES  \
# 0               Avengers: Age of Ultron (2015)    5.0     4.5  14846.0
# 1                            Cinderella (2015)    5.0     4.5  12640.0
# 2                               Ant-Man (2015)    5.0     4.5  12055.0
# 3                       Do You Believe? (2015)    5.0     4.5   1793.0
# 4                Hot Tub Time Machine 2 (2015)    3.5     3.0   1021.0
# ..                                         ...    ...     ...      ...
# 141                          Mr. Holmes (2015)    4.0     4.0   1348.0
# 142                                 '71 (2015)    3.5     3.5    192.0
# 143                 Two Days, One Night (2014)    3.5     3.5    118.0
# 144  Gett: The Trial of Viviane Amsalem (2015)    3.5     3.5     59.0
# 145         Kumiko, The Treasure Hunter (2015)    3.5     3.5     41.0
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                74                   86          66              7.1   7.8
# 1                85                   80          67              7.5   7.1
# 2                80                   90          64              8.1   7.8
# 3                18                   84          22              4.7   5.4
# 4                14                   28          29              3.4   5.1
# ..              ...                  ...         ...              ...   ...
# 141              87                   78          67              7.9   7.4
# 142              97                   82          83              7.5   7.2
# 143              97                   78          89              8.8   7.4
# 144             100                   81          90              7.3   7.8
# 145              87                   63          68              6.4   6.7
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 0                          1330                271107
# 1                           249                 65709
# 2                           627                103660
# 3                            31                  3136
# 4                            88                 19560
# ..                          ...                   ...
# 141                          33                  7367
# 142                          60                 24116
# 143                         123                 24345
# 144                          19                  1955
# 145                          19                  5289
#
# [146 rows x 11 columns]

# %%
mergedFandango = pd.merge(fandango, all_sites, how = 'inner', on = 'FILM')
mergedFandango
# Out:
#                                    FILM  STARS  RATING  VOTES  RottenTomatoes  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846              25
# 1                 Jurassic World (2015)    4.5     4.5  34390              71
# 2                American Sniper (2015)    5.0     4.8  34085              72
# 3                      Furious 7 (2015)    5.0     4.8  33538              81
# 4                     Inside Out (2015)    4.5     4.5  15749              98
# ..                                  ...    ...     ...    ...             ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41              87
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38              95
# 142            The Wrecking Crew (2015)    4.5     4.2     38              93
# 143                    Tangerine (2015)    4.0     3.9     36              95
# 144            Maps to the Stars (2015)    3.5     3.1     35              60
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     42          46              3.2   4.2
# 1                     81          59              7.0   7.3
# 2                     85          72              6.6   7.4
# 3                     84          67              6.8   7.4
# 4                     90          94              8.9   8.6
# ..                   ...         ...              ...   ...
# 140                   63          68              6.4   6.7
# 141                   81          87              6.3   7.0
# 142                   84          67              7.0   7.8
# 143                   86          86              7.3   7.4
# 144                   46          67              5.8   6.3
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 0                           778                179506
# 1                          1281                241807
# 2                           850                251856
# 3                           764                207211
# 4                           807                 96252
# ..                          ...                   ...
# 140                          19                  5289
# 141                          18                  1107
# 142                           4                   732
# 143                          14                   696
# 144                          46                 22440
#
# [145 rows x 11 columns]

# %% [markdown]
# I noticed that *inner* merged table has 1 less film than the all_sites table, I want to know what is the name of that film. One film must have NaN value in minimum one column, cell below confirms that. Because of the right join, left table (fandango) will contain NaN values if both tables don't share same cell.

# %%
test = rightMerged.dropna()
test
# Out:
#                                           FILM  STARS  RATING    VOTES  \
# 0               Avengers: Age of Ultron (2015)    5.0     4.5  14846.0
# 1                            Cinderella (2015)    5.0     4.5  12640.0
# 2                               Ant-Man (2015)    5.0     4.5  12055.0
# 3                       Do You Believe? (2015)    5.0     4.5   1793.0
# 4                Hot Tub Time Machine 2 (2015)    3.5     3.0   1021.0
# ..                                         ...    ...     ...      ...
# 141                          Mr. Holmes (2015)    4.0     4.0   1348.0
# 142                                 '71 (2015)    3.5     3.5    192.0
# 143                 Two Days, One Night (2014)    3.5     3.5    118.0
# 144  Gett: The Trial of Viviane Amsalem (2015)    3.5     3.5     59.0
# 145         Kumiko, The Treasure Hunter (2015)    3.5     3.5     41.0
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                74                   86          66              7.1   7.8
# 1                85                   80          67              7.5   7.1
# 2                80                   90          64              8.1   7.8
# 3                18                   84          22              4.7   5.4
# 4                14                   28          29              3.4   5.1
# ..              ...                  ...         ...              ...   ...
# 141              87                   78          67              7.9   7.4
# 142              97                   82          83              7.5   7.2
# 143              97                   78          89              8.8   7.4
# 144             100                   81          90              7.3   7.8
# 145              87                   63          68              6.4   6.7
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 0                          1330                271107
# 1                           249                 65709
# 2                           627                103660
# 3                            31                  3136
# 4                            88                 19560
# ..                          ...                   ...
# 141                          33                  7367
# 142                          60                 24116
# 143                         123                 24345
# 144                          19                  1955
# 145                          19                  5289
#
# [145 rows x 11 columns]

# %%
rightMerged
# Out:
#                                           FILM  STARS  RATING    VOTES  \
# 0               Avengers: Age of Ultron (2015)    5.0     4.5  14846.0
# 1                            Cinderella (2015)    5.0     4.5  12640.0
# 2                               Ant-Man (2015)    5.0     4.5  12055.0
# 3                       Do You Believe? (2015)    5.0     4.5   1793.0
# 4                Hot Tub Time Machine 2 (2015)    3.5     3.0   1021.0
# ..                                         ...    ...     ...      ...
# 141                          Mr. Holmes (2015)    4.0     4.0   1348.0
# 142                                 '71 (2015)    3.5     3.5    192.0
# 143                 Two Days, One Night (2014)    3.5     3.5    118.0
# 144  Gett: The Trial of Viviane Amsalem (2015)    3.5     3.5     59.0
# 145         Kumiko, The Treasure Hunter (2015)    3.5     3.5     41.0
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                74                   86          66              7.1   7.8
# 1                85                   80          67              7.5   7.1
# 2                80                   90          64              8.1   7.8
# 3                18                   84          22              4.7   5.4
# 4                14                   28          29              3.4   5.1
# ..              ...                  ...         ...              ...   ...
# 141              87                   78          67              7.9   7.4
# 142              97                   82          83              7.5   7.2
# 143              97                   78          89              8.8   7.4
# 144             100                   81          90              7.3   7.8
# 145              87                   63          68              6.4   6.7
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 0                          1330                271107
# 1                           249                 65709
# 2                           627                103660
# 3                            31                  3136
# 4                            88                 19560
# ..                          ...                   ...
# 141                          33                  7367
# 142                          60                 24116
# 143                         123                 24345
# 144                          19                  1955
# 145                          19                  5289
#
# [146 rows x 11 columns]

# %%
rightMergedTest = rightMerged.fillna(-1)
def nanmovie(movie):
    if(movie == -1):
        return movie
    else:
        return 0

rightMergedTest['VOTES'].apply(nanmovie).value_counts()
rightMergedTest[rightMergedTest['VOTES'] == -1]
# Out:
#                                             FILM  STARS  RATING  VOTES  \
# 128  Mission: Impossible â€“ Rogue Nation (2015)   -1.0    -1.0   -1.0
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 128              92                   90          75              8.0   7.8
#
#      Metacritic_user_vote_count  IMDB_user_vote_count
# 128                         362                 82579

# %%
rightMerged.iloc[128]
# Out:
# FILM                          Mission: Impossible â€“ Rogue Nation (2015)
# STARS                                                                 NaN
# RATING                                                                NaN
# VOTES                                                                 NaN
# RottenTomatoes                                                         92
# RottenTomatoes_User                                                    90
# Metacritic                                                             75
# Metacritic_User                                                       8.0
# IMDB                                                                  7.8
# Metacritic_user_vote_count                                            362
# IMDB_user_vote_count                                                82579
# Name: 128, dtype: object

# %% [markdown]
# ### Converting columns to Fandango STARS and RATINGS 0-5
#
# RT,Metacritic, and IMDB don't use a score between 0-5 stars like Fandango does. In order to do a fair comparison, I need to *normalize* these values so they all fall between 0-5 stars and the relationship between reviews stays the same.
#
# **TASK: Create new converted columns for all ratings so they match up within the 0-5 star range shown on Fandango.**

# %%
mergedFandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846              25
# 1        Jurassic World (2015)    4.5     4.5  34390              71
# 2       American Sniper (2015)    5.0     4.8  34085              72
# 3             Furious 7 (2015)    5.0     4.8  33538              81
# 4            Inside Out (2015)    4.5     4.5  15749              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count
# 0                         778                179506
# 1                        1281                241807
# 2                         850                251856
# 3                         764                207211
# 4                         807                 96252

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
convertedDataFrame = pd.DataFrame({'FILM' : mergedFandango['FILM'], 'Stars_Fandango' : mergedFandango['STARS'], 
                                   'Rating_Fandango' : mergedFandango['RATING'], 'RottenTomatoes' : mergedFandango['RottenTomatoes'] / 20, 
                                   'RottenTomatoes_User' : mergedFandango['RottenTomatoes_User'] / 20, 'Metacritic' : mergedFandango['Metacritic'] / 20, 
                                   'Metacritic_User' : mergedFandango['Metacritic_User'] / 2, 'IMDB' : mergedFandango['IMDB'] / 2})
convertedDataFrame
# Out:
#                                    FILM  Stars_Fandango  Rating_Fandango  \
# 0           Fifty Shades of Grey (2015)             4.0              3.9
# 1                 Jurassic World (2015)             4.5              4.5
# 2                American Sniper (2015)             5.0              4.8
# 3                      Furious 7 (2015)             5.0              4.8
# 4                     Inside Out (2015)             4.5              4.5
# ..                                  ...             ...              ...
# 140  Kumiko, The Treasure Hunter (2015)             3.5              3.5
# 141  The Diary of a Teenage Girl (2015)             4.0              3.6
# 142            The Wrecking Crew (2015)             4.5              4.2
# 143                    Tangerine (2015)             4.0              3.9
# 144            Maps to the Stars (2015)             3.5              3.1
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB
# 0              1.25                 2.10        2.30             1.60  2.10
# 1              3.55                 4.05        2.95             3.50  3.65
# 2              3.60                 4.25        3.60             3.30  3.70
# 3              4.05                 4.20        3.35             3.40  3.70
# 4              4.90                 4.50        4.70             4.45  4.30
# ..              ...                  ...         ...              ...   ...
# 140            4.35                 3.15        3.40             3.20  3.35
# 141            4.75                 4.05        4.35             3.15  3.50
# 142            4.65                 4.20        3.35             3.50  3.90
# 143            4.75                 4.30        4.30             3.65  3.70
# 144            3.00                 2.30        3.35             2.90  3.15
#
# [145 rows x 8 columns]

# %% [markdown]
# ### Comparing Distribution of Scores Across Sites
#
#
# We already know it pushs displayed RATING higher than STARS, but are the ratings themselves higher than average?
#
#
# **TASK: Create a plot comparing the distributions of converted ratings across all sites.**

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig, ax = plt.subplots(figsize=(12, 5), dpi=150)
ax.set_xlabel('Rating')

sns.kdeplot(data=convertedDataFrame, fill=True, palette="Set1", clip=(0, 5), ax=ax);

move_legend(ax, "upper left")
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jovan\AppData\Local\Temp\ipykernel_16992\191327130.py:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = old_legend.legendHandles

# %% [markdown]
# **Clearly Fandango has an uneven distribution. I can also see that RT critics have the most uniform distribution.**
#
# **TASK: Create a KDE plot that compare the distribution of RT critic ratings against the STARS displayed by Fandango.**

# %%
fig, ax = plt.subplots(figsize = (12, 6), dpi = 200)
sns.kdeplot(data = convertedDataFrame[['RottenTomatoes', 'Stars_Fandango']], fill = True, palette = 'Set1', clip = [0, 5])
move_legend(ax, "upper left")
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jovan\AppData\Local\Temp\ipykernel_16992\191327130.py:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = old_legend.legendHandles

# %% [markdown]
# **TASK: Create a histplot comparing all converted scores.**

# %%
plt.figure(figsize = (12, 5), dpi = 150)
sns.histplot(data = convertedDataFrame, bins = 50);
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### How are the worst movies rated across all platforms?
#
# **TASK: Create a clustermap visualization of all normalized scores. Note the differences in ratings, highly rated movies should be clustered together versus poorly rated movies.**

# %%
sns.clustermap(data = convertedDataFrame.drop('FILM', axis = 1))

# %% [markdown]
# **TASK: Clearly Fandango is rating movies much higher than other sites, especially considering that it is then displaying a rounded up version of the rating. Let's examine the top 10 worst movies. Based off the Rotten Tomatoes Critic Ratings, what are the top 10 lowest rated movies? What are the normalized scores across all platforms for these movies? You may need to add the FILM column back in to your DataFrame of normalized scores to see the results.**

# %%
convertedDataFrame.head()
# Out:
#                           FILM  Stars_Fandango  Rating_Fandango  \
# 0  Fifty Shades of Grey (2015)             4.0              3.9
# 1        Jurassic World (2015)             4.5              4.5
# 2       American Sniper (2015)             5.0              4.8
# 3             Furious 7 (2015)             5.0              4.8
# 4            Inside Out (2015)             4.5              4.5
#
#    RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB
# 0            1.25                 2.10        2.30             1.60  2.10
# 1            3.55                 4.05        2.95             3.50  3.65
# 2            3.60                 4.25        3.60             3.30  3.70
# 3            4.05                 4.20        3.35             3.40  3.70
# 4            4.90                 4.50        4.70             4.45  4.30

# %%
convertedDataFrame.nsmallest(10, 'RottenTomatoes')
# Out:
#                              FILM  Stars_Fandango  Rating_Fandango  \
# 49  Paul Blart: Mall Cop 2 (2015)             3.5              3.5
# 84        Hitman: Agent 47 (2015)             4.0              3.9
# 54             Hot Pursuit (2015)             4.0              3.7
# 25                 Taken 3 (2015)             4.5              4.1
# 28          Fantastic Four (2015)             3.0              2.7
# 50       The Boy Next Door (2015)             4.0              3.6
# 87     Unfinished Business (2015)             3.5              3.2
# 88                The Loft (2015)             4.0              3.6
# 77             Seventh Son (2015)             3.5              3.2
# 78               Mortdecai (2015)             3.5              3.2
#
#     RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB
# 49            0.25                 1.80        0.65             1.20  2.15
# 84            0.35                 2.45        1.40             1.65  2.95
# 54            0.40                 1.85        1.55             1.85  2.45
# 25            0.45                 2.30        1.30             2.30  3.05
# 28            0.45                 1.00        1.35             1.25  2.00
# 50            0.50                 1.75        1.50             2.75  2.30
# 87            0.55                 1.35        1.60             1.90  2.70
# 88            0.55                 2.00        1.20             1.20  3.15
# 77            0.60                 1.75        1.50             1.95  2.75
# 78            0.60                 1.50        1.35             1.60  2.75

# %% [markdown]
# **FINAL TASK: Visualize the distribution of ratings across all sites for the top 10 worst movies.**

# %%
plt.figure(figsize = (12, 5), dpi = 150)
plt.title("Ratings for RT Critic's for 10 Worst Reviewed Films")
sns.kdeplot(data = convertedDataFrame.nsmallest(10, 'RottenTomatoes'), fill = True)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': "Ratings for RT Critic's for 10 Worst Reviewed Films"}, ylabel='Density'>

# %%
def worstMovie(one, two, three, four):
    return (one + two + three + four) / 4

def ratio(stars, average):
    return stars - average
    
convertedDataFrame['WorstAverageRating'] = np.vectorize(worstMovie)(convertedDataFrame['RottenTomatoes'], convertedDataFrame['RottenTomatoes_User'],
                                                                   convertedDataFrame['Metacritic'], convertedDataFrame['Metacritic_User'])
convertedDataFrame.sort_values('WorstAverageRating', ascending = True)
convertedDataFrame['WorstMovieRatio'] = np.vectorize(ratio)(convertedDataFrame['Stars_Fandango'], convertedDataFrame['WorstAverageRating'])
convertedDataFrame.sort_values('WorstMovieRatio', ascending = False)
# Out:
#                                           FILM  Stars_Fandango  \
# 25                              Taken 3 (2015)             4.5
# 67                      Do You Believe? (2015)             5.0
# 88                             The Loft (2015)             4.0
# 40                               Pixels (2015)             4.5
# 54                          Hot Pursuit (2015)             4.0
# ..                                         ...             ...
# 110                                 '71 (2015)             3.5
# 128  Gett: The Trial of Viviane Amsalem (2015)             3.5
# 123                             Phoenix (2015)             3.5
# 115                 Two Days, One Night (2014)             3.5
# 61                           It Follows (2015)             3.0
#
#      Rating_Fandango  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 25               4.1            0.45                 2.30        1.30
# 67               4.5            0.90                 4.20        1.10
# 88               3.6            0.55                 2.00        1.20
# 40               4.1            0.85                 2.70        1.35
# 54               3.7            0.40                 1.85        1.55
# ..               ...             ...                  ...         ...
# 110              3.5            4.85                 4.10        4.15
# 128              3.5            5.00                 4.05        4.50
# 123              3.4            4.95                 4.05        4.55
# 115              3.5            4.85                 3.90        4.45
# 61               2.9            4.80                 3.25        4.15
#
#      Metacritic_User  IMDB  WorstAverageRating  WorstMovieRatio
# 25              2.30  3.05              1.5875           2.9125
# 67              2.35  2.70              2.1375           2.8625
# 88              1.20  3.15              1.2375           2.7625
# 40              2.65  2.80              1.8875           2.6125
# 54              1.85  2.45              1.4125           2.5875
# ..               ...   ...                 ...              ...
# 110             3.75  3.60              4.2125          -0.7125
# 128             3.65  3.90              4.3000          -0.8000
# 123             4.00  3.60              4.3875          -0.8875
# 115             4.40  3.70              4.4000          -0.9000
# 61              3.75  3.45              3.9875          -0.9875
#
# [145 rows x 10 columns]

# %% [markdown]
# **Final conclusion: Fandango is clearly showing fake ratings. Ratings on Fandango are not below 2.5, which can not be case when compare with other sites. The biggest offender is *Taken 3*. Fandango is displaying 4.5 stars on their site for a film with an average rating of 1.58 across the other platforms. Fandango's rating for *Teken 3* is higher for almost 3 stars in comparison to other sites!**
